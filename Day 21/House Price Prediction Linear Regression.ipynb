# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Linear Regression.xlsx",sheet_name=0)
data.head()
# Out:
#     price  sqft_living  bedrooms  bathrooms  floors
# 0  221900         1180         3       1.00     1.0
# 1  538000         2570         3       2.25     2.0
# 2  180000          770         2       1.00     1.0
# 3  604000         1960         4       3.00     1.0
# 4  510000         1680         3       2.00     1.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 5 columns):
# price          21613 non-null int64
# sqft_living    21613 non-null int64
# bedrooms       21613 non-null int64
# bathrooms      21613 non-null float64
# floors         21613 non-null float64
# dtypes: float64(2), int64(3)
# memory usage: 844.3 KB

# %%
data.shape
# Out:
# (21613, 5)

# %%
sns.pairplot(data)
plt.show()

# %%
sns.boxplot(data.price, orient= "vertical")
plt.show()

# %%
sns.boxplot(data.sqft_living, orient= "vertical")
plt.show()

# %%
sns.boxplot(data.bedrooms, orient= "vertical")
plt.show()

# %%
sns.boxplot(data.bathrooms, orient= "vertical")
plt.show()

# %%
sns.boxplot(data.floors, orient= "vertical")
plt.show()

# %%
sns.distplot(data.price)
plt.show()

# %%
sns.distplot(data.sqft_living)
plt.show()

# %%
sns.distplot(data.bathrooms)
plt.show()

# %%
sns.distplot(data.bedrooms)
plt.show()

# %%
sns.distplot(data.floors)
plt.show()

# %% [markdown]
# # Data Visualization Inferences
#
# 1) The dependent variable price is left skewed and has many outliers.
#
# 2) The independent variable area of living in square feet is left skewed and has many outliers.
#
# 3) The independent variable number of bedrooms is left skewed and has moderate outliers.
#
# 4) The independent variable number of bathrooms has moderate outliers.
#
# 5) The independent variable number of floors is has no outliers.

# %%
data.corr()
# Out:
#                 price  sqft_living  bedrooms  bathrooms    floors
# price        1.000000     0.702035  0.308350   0.525138  0.256794
# sqft_living  0.702035     1.000000  0.576671   0.754665  0.353949
# bedrooms     0.308350     0.576671  1.000000   0.515884  0.175429
# bathrooms    0.525138     0.754665  0.515884   1.000000  0.500653
# floors       0.256794     0.353949  0.175429   0.500653  1.000000

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %% [markdown]
# # Model Testing

# %% [markdown]
# __Price as dependent variable and area of living in square feet, number of bedrooms,number of bathrooms and number of floors as independent variables. Since all the varbiarbles are continuous a munltiple linear regression model is used.__

# %%
x = data.iloc[:,1:5]
y = data.iloc[:,:1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()

# %%
lreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = lreg.predict(X_test)
predictions
# Out:
# array([[  418082.2070007 ],
#        [ 1306707.47771871],
#        [  409588.1373233 ],
#        ...,
#        [  583468.89595792],
#        [  373227.82730922],
#        [  321070.6451827 ]])

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("R squre value is: ", r2_score(y_test,predictions))
print("RMSE value is: ", np.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# R squre value is:  0.506328262165
# RMSE value is:  260340.458086

# %% [markdown]
# # Inference
#
# 1) R-square value is 0.5 suggesting that only about 50% or half of the variance in the target variable i.e. price can be explained by the independent variables area of living, number of bedrooms,number of bathrooms and number of floors.
#
# 2) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).

# %% [markdown]
# ### Now we are going to check all the indepedent variable relations with the depedent variable one by one

# %% [markdown]
# # Model 1
#
# __Prive VS Sqft living__
#
# Price as dependent variable and area of living in square feet as independent variable. Since both the variables are continuous a simple linear regression model is used.

# %%
x1 = data.iloc[:,1:2]

# %%
from sklearn.model_selection import train_test_split
X1_train,X1_test,y1_train,y1_test = train_test_split(x1,y, test_size = 0.3, random_state =10)

# %%
lreg1= LinearRegression()

# %%
lreg1.fit(X1_train,y1_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions1 = lreg1.predict(X1_test)

# %%
print("R squre value is: ", r2_score(y1_test,predictions1))
print("RMSE value is: ", np.sqrt(mean_squared_error(y1_test, predictions1)))
# Out:
# R squre value is:  0.499261316554
# RMSE value is:  262809.040266

# %% [markdown]
# # Inference
#
# 1) R-square value is 0.49 suggesting that only about 49% of the variance in the target variable i.e. price can be explained by the independent variable area of living.
#
# 2) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).

# %% [markdown]
# # Model 2
#
# __Prive VS Bedrooms__
#
# Price as dependent variable and number of bedrooms as independent variable. Since both the varbiarbles are continuous a simple linear regression model is used.

# %%
x2=data.iloc[:,2:3]

# %%
from sklearn.model_selection import train_test_split
X2_train,X2_test,y2_train,y2_test = train_test_split(x2,y, test_size = 0.3, random_state =10)

# %%
lreg2 = LinearRegression()

# %%
lreg2.fit(X2_train,y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions2 = lreg2.predict(X2_test)

# %%
print("R squre value is: ", r2_score(y2_test,predictions2))
print("RMSE value is: ", np.sqrt(mean_squared_error(y2_test, predictions2)))
# Out:
# R squre value is:  0.105410605576
# RMSE value is:  351274.48141

# %% [markdown]
# # Inferences
#
# 1) R-square value is 0.10 suggesting that only about 10% of the variance in the target variable i.e. price can be explained by the independent variable number of bedrooms.
#
# 2) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).

# %% [markdown]
# # Model 3
#
# __Prive VS Bathrooms__
#
# Price as dependent variable and number of bathrooms as independent variable. Since both the varbiarbles are continuous a simple linear regression model is used.

# %%
x3 = data.iloc[:,3:4]

# %%
from sklearn.model_selection import train_test_split
X3_train,X3_test,y3_train,y3_test = train_test_split(x3,y, test_size = 0.3, random_state = 1)

# %%
lreg3 = LinearRegression()

# %%
lreg3.fit(X3_train,y3_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions3 = lreg3.predict(X3_test)

# %%
print("R squre value is: ", r2_score(y3_test,predictions3))
print("RMSE value is: ", np.sqrt(mean_squared_error(y3_test, predictions3)))
# Out:
# R squre value is:  0.284246797157
# RMSE value is:  334227.215795

# %% [markdown]
# # Inference
#
# 1) R-square value is 0.28 suggesting that only about 28% of the variance in the target variable i.e. price can be explained by the independent variable number of bathrooms.
#
# 2) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).

# %% [markdown]
# # Model 4
#
# __Prive VS Floors__
#
# Price as dependent variable and number of floors as independent variable. Since both the varbiarbles are continuous a simple linear regression model is used.

# %%
x4 = data.iloc[:,4:]

# %%
from sklearn.model_selection import train_test_split
X4_train,X4_test,y4_train,y4_test = train_test_split(x4,y, test_size = 0.3, random_state = 10)

# %%
lreg4 = LinearRegression()

# %%
lreg4.fit(X4_train,y4_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions4 = lreg4.predict(X4_test)

# %%
print("R squre value is: ", r2_score(y4_test,predictions4))
print("RMSE value is: ", np.sqrt(mean_squared_error(y4_test, predictions4)))
# Out:
# R squre value is:  0.0669120102371
# RMSE value is:  358753.402262

# %% [markdown]
# # Inference
#
# 1) R-square value is 0.06 suggesting that only about 6% of the variance in the target variable i.e. price can be explained by the independent variable number of floors.
#
# 2) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).
